# %% [markdown]
# <a href="https://colab.research.google.com/github/meowmi-i/first-ml/blob/main/MHI2002_Building_ML_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing PyCaret

# %%
# !pip install pycaret

# %% [markdown]
# #Step 1: Load Dataset

# %%
# load dataset
import random
random.seed(42)

import pandas as pd

file_url = "https://raw.githubusercontent.com/saeid-uot/UoT_MHI/main/Assignment%202/Dataset/watson_healthcare_modified.csv"

health_churn = pd.read_csv(file_url)

# %%
health_churn.shape
# Out:
# (1676, 35)

# %%
health_churn
# Out:
#       EmployeeID  Age Attrition     BusinessTravel  DailyRate  Department  \
# 0        1313919   41        No      Travel_Rarely       1102  Cardiology
# 1        1200302   49        No  Travel_Frequently        279   Maternity
# 2        1060315   37       Yes      Travel_Rarely       1373   Maternity
# 3        1272912   33        No  Travel_Frequently       1392   Maternity
# 4        1414939   27        No      Travel_Rarely        591   Maternity
# ...          ...  ...       ...                ...        ...         ...
# 1671     1117656   26       Yes      Travel_Rarely        471   Neurology
# 1672     1152327   46        No      Travel_Rarely       1125  Cardiology
# 1673     1812428   20        No      Travel_Rarely        959   Maternity
# 1674     1812429   39        No      Travel_Rarely        466   Neurology
# 1675     1152329   27        No      Travel_Rarely        511  Cardiology
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  ...  \
# ...

# %%
mean_age = health_churn['Age'].mean()
print(f"The mean age of employees is: {mean_age:.2f}")
# Out:
# The mean age of employees is: 36.87

# %%
attrition_counts = health_churn['Attrition'].value_counts()
print(attrition_counts)
# Out:
# Attrition
# No     1477
# Yes     199
# Name: count, dtype: int64

# %% [markdown]
# #Step 2: Initiate/Setup PyCaret

# %%
from pycaret.classification import *
pycaret_setup = setup(data=health_churn, target='Attrition', session_id=123)
# Out:
# <style type="text/css">
# #T_b25bc_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b25bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b25bc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b25bc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b25bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b25bc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b25bc_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b25bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b25bc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b25bc_row1_col1" class="data row1 col1" >Attrition</td>
#     </tr>
#     <tr>
#       <th id="T_b25bc_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# #Step 3: Create Model!

# %%
mymodel = compare_models()#'lr')#,sort="F1")
# Out:
# <style type="text/css">
# #T_d2f70 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# #Evaluate Model

# %%
evaluate_model(mymodel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
